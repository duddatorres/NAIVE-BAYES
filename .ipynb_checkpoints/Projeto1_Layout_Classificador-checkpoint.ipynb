# %% [markdown]
# # Projeto 1 - Ciência dos Dados

# %% [markdown]
# Nome: Maria Eduarda Torres
#
# Nome: Giancarlo

# %% [markdown]
# Atenção: Serão permitidos grupos de três pessoas, mas com uma rubrica mais exigente. Grupos deste tamanho precisarão fazer um questionário de avaliação de trabalho em equipe

# %% [markdown]
# ___
# Carregando algumas bibliotecas:

# %%
# %matplotlib inline
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import os
import re 
import numpy
import itertools
import collections
import functools
import operator
import emoji

# %%
print('Esperamos trabalhar no diretório')
print(os.getcwd())
# Out:
# Esperamos trabalhar no diretório
# /Users/duddatorres/Documents/PESSOAL/NAIVE-BAYES

# %% [markdown]
# Carregando a base de dados com os tweets classificados como relevantes e não relevantes:

# %%
filename = 'iphone_12.xlsx'

# %%
train = pd.read_excel(filename)
train
# Out:
#                                            Treinamento  categorias
# 0    até junho compro meu iphone 12 pro max se deus...           1
# 1    lembrando do dia que eu derrubei um iphone 12 ...           0
# 2                     alguém me da um iphone 12 ai pfv           1
# 3    vem projota quero ganhar um iphone 12 que eu p...           1
# 4    saí mt lindo na foto da identidade mane, camer...           1
# 5            " #tbt 2019 *-* "\no iphone 12 no espelho           0
# 6    na dúvida se compro o iphone 12 pro max ou um ...           0
# 7    @lima_arthurcp deus é mais!!!\n40k eu compro o...           0
# 8    @o_antagonista alguém calcula aí pra mim quant...           0
# 9    rt @nahcardoso: hoje tem keynote da @apple as ...           1
# 10   @samsungbrasil engraçado que no facebook vocês...           0
# 11   @linharxz @fuckhlz celular: não vai ter até co...           1
# 12   iphone salva muito nas fotos.. \nfale por você...           0
# 13   asus zenfone 8 mini deve chegar com tela peque...           0
# 14   hoje é pelo iphone 12, amanhã é pelo carregado...           0
# 15   o famoso que distribui iphone 12 de brinde de ...           0
# 16   vídeo novo! garimpei um iphone 12 mini na olx!...           1
# 17   eu quero! clique no link para me ajudar a baix...           1
# 18    um iphone 12 na minha mão, eu nn reclamaria mais           1
# 19   pelo menos com um iphone eu só fico endividado...           1
# 20   era só um iphone 12 pro max 256g pra eu sair d...           1
# 21   e o senhorzinho de uns 80 anos ostentando seu ...           1
# 22            era só um iphone 12 na minha vida aff 🙄😑           1
# 23          @mmmanys queee???? 9k é preço de iphone 12           1
# 24   amanhã sai o resultado do sorteio será que gan...           1
# 25   só q no caso da p comprar uns 6 iphone 12 com ...           0
# 26   lindo mas o preço da pra comprar iphone 12, ma...           0
# 27   kiiti me ensina a apostar e fazer meu dinheiro...           0
# 28   volta comigo bebê do zé vaqueiro foi gravado c...           1
# 29   rt @erickadams0: queria ser a tainá, eu ia peg...           1
# 30            @13_levi dá pra comprar uns 10 iphone 12           0
# 31   se a mjnha mae pegar o iphoen 12 ela vai aaber...           0
# 32   @appeltstefany @seventthinggs já achei que tua...           0
# 33   eu quero! clique no link para me ajudar a baix...           0
# 34   alguém sabe se as capinhas do iphone 11 serve ...           0
# 35   curti muito o iphone 12 mas pqp que telefone p...           1
# 36   será q agr eu compro meu iphone 12? https://t....           0
# 37   @googieweb não vai ter eu ganhando um iphone 1...           0
# 38         @elonmusk verdade lindo me dá um iphone 12?           1
# 39   @znt_biel @_lohans @henrique_thug69 @matheus_a...           0
# 40   plot: com um desse daria pra compra de 2 a 3 i...           0
# 41          mano ninguém quer ver o teu iphone 12 vtnc           1
# 42   @giinitri simmm as véia vão me achar gostoso e...           1
# 43   dá vontade de me matar quando vejo o iphone 12...           0
# 44   @avelarvick1 eu tenho fé que o iphone 12 sai u...           1
# 45   logo eu q sempre defendi o android, acabo de c...           1
# 46   🍎 🍏 esse é pra quem tem bala na agulha        ...           0
# 47   fui vê a poha daquele do iphone 12 xeee parcel...           0
# 48   iphone 12 pro de 512gb, de r$12.999 por r$9.98...           0
# 49    a eu queria um iphone 12 https://t.co/swvsh48rr6           1
# 50   @lguto_ds kkkkkk poise, vc tb nem p me dar um ...           1
# 51   rt @chatonmlb: como ter câmera de iphone 12 em...           0
# 52   eu sou o tipo de pessoa que se alegra com qual...           1
# 53   e a minha amiga q ganhou iphone 12 do suga.. d...           1
# 54   @mnuellap não vai ter eu ganhando um iphone 12...           0
# 55   iphone 12 pro max\n128gb\n256gb\n[selado]\n\na...           0
# 56   se bem q kindle e pouco se for pensar q ele nã...           1
# 57   cade os iphone 11 12 quente com icloud liberad...           1
# 58   amigas ou namorado comprem la o iphone 12 pro ...           1
# 59   mano a câmera do iphone 12 é literalmente melh...           1
# 60   além da eliminação do projota, o que me faria ...           1
# 61         @neymarjr verdade ídolo, me dá o iphone 12?           1
# 62   @idkmaryt por esse preço eu compro um iphone 1...           0
# 63   aqui esperando ele se declarar pra mim com buq...           0
# 64   sim gata você ganhou um iphone 12 pq vc acredi...           1
# 65   vou ver o sorteio do iphone 12 kkkkk q eu sei ...           0
# 66   os de hj já nascem com iphone 12 https://t.co/...           1
# 67   @assumps @nanicv ela trocou carro num iphone 1...           1
# 68    algum árabe rico online pra me dar um iphone 12?           1
# 69   @googieweb não vai ter eu ganhando um iphone 1...           0
# 70   @neppel8 @luxavier_b @chuntana5 nem me deu um ...           0
# 71   sdds de entrar na toro de um gringo que eu nun...           0
# 72   com essa chuvona em fortaleza, bem que podia c...           1
# 73   sim sim flores, vocês vão ganhar um iphone 12 ...           1
# 74   velocidade do 5g no iphone 12 está muito longe...           1
# 75   a asus pode lançar um pequeno zenfone 8 para c...           1
# 76                  alguém compra um iphone 12 pra mim           1
# 77             qria comprar um iphone 12 com 10$ reais           1
# 78                     ah pronto agr quero o iphone 12           1
# 79   gente com 19-20 anos com um salário em média d...           1
# 80   @jonasdiandrade @giorrdanna a merda desse comp...           1
# 81            fogo no colômbia gold, foto no iphone 12           1
# 82   iphone 12 pro max 128gb - disponível https://t...           0
# 83   @azksnialler não vai ter eu ganhando um iphone...           0
# 84   não vai ter eu ganhando o iphone 12 de anivers...           0
# 85   @googieweb não vai ter eu ganhando um iphone 1...           0
# 86   samsung promete até 3 atualizações do android ...           1
# 87   recebi um e-mail da iplace! \nnão queria nem o...           0
# 88             quero meu iphone 12 na minha casa agora           1
# 89   tem cara de iphone 12 pro max apple 256gb dura...           1
# 90   rt @_boiolinha: o iphone das sterellas não agu...           0
# 91   @lumartelli @gadodecider não fica triste 🤗mesm...           1
# 92   pensando aqui se vale a pena gastar o preço de...           0
# 93   não, eu não ganhei esse iphone 12 porque a min...           0
# 94   rt @crfxulia_: um iphone 12 na minha mão, eu n...           1
# 95   @larissiiv @caupzz já não bastava o iphone 12 ...           1
# 96   prefiro comprar a land rover e um iphone 12 pr...           1
# 97   @_beeaatrizg eu vi isso e pensei hmm queria um...           1
# 98   compra iphone 12 o caralho eu quero isso aqui ...           1
# 99   kkkkkk coitado do oliver nem sabe onde se mete...           0
# 100  ou você compra ou dá rt para alguém comprar, v...           0
# 101  torcendo pra ganhar o iphone 12 no sorteio do ...           1
# 102    queria comprar um iphone 12 no trem por 5 reais           1
# 103  @jenbzr af mas eu quero tanto trocar de celula...           1
# 104  @crf_raphad o iphone é o 11 e as parcelas fora...           1
# 105  @googieweb não vai ter eu com um setupzao game...           0
# 106   @patrickpzt auahauahauahua agora vem o iphone 12           1
# 107  @fabiofaria5555 @mineconomia opa agora da pra ...           1
# 108  rt @edupaivastore: 🤳🏾 iphone 12 pro apple 128g...           0
# 109  @bellekaffer carai, vamo na loja p vc comprar ...           1
# 110  #promoção #oferta  [marketplace] [ame por 6.87...           0
# 111  eu nem sabia que já existia iphone 12 \neu não...           1
# 112          algum suggar p tá me doando um iphone 12?           1
# 113  galaxy s21 ultra espancando a câmera do iphone...           1
# 114  @pontofrio bom dia pin, acordei com uma vontad...           1
# 115  rt @zezzziin: um árabe me chamou na dm, se eu ...           1
# 116  por esse preço eu compro um iphone 12, um macb...           0
# 117                @gusoutulio eu quero é um iphone 12           1
# 118  @emimaaay compra um iphone 12 boatos que é bai...           1
# 119  só aceito ovo de páscoa se vir com um iphone 1...           1
# 120  rt @haroldloueh28: o que custa alguém me dá um...           1
# 121  rt @mateus_zian: qria comprar um iphone 12 com...           1
# 122  sugestões de presente: (meu aniv 04/04)\n-ipho...           0
# 123  por esse preço eu compro um iphone 12 um macbo...           0
# 124  rt @bemigueel: @jonasdiandrade por esse preço ...           0
# 125  engraçado que 4 iphone 12 pro max dão um noteb...           0
# 126  com o valor dessa porra eu compro um celta e u...           0
# 127  sonhei q eu tava c um iphone 12  senhor eu to ...           1
# 128  o seu perfil foi visto por 8 pessoas nas últim...           0
# 129  pensando em trocar de samsung pra iphone, mas ...           1
# 130                era só um iphone 12 na minha vida:(           1
# 131  @lucasranngel me dá um iphone 12 pro max top d...           1
# 132  sugestões de presente: (meu aniv 06/04)\n-ipho...           0
# 133  rt @joaocyrilo: quem tem seu iate, sua ilha, o...           0
# 134  @filipeesposito @clarobrasil agora é a última ...           0
# 135  mas tb se um dia for de eu ter, só vai subir n...           1
# 136  tipo rico quando lança um iphone novo https://...           1
# 137  @ydiamondd @realgabrieladol para mano, ela que...           1
# 138  uns desejando iphone 12 eu só quero ter esse v...           1
# 139  alguém sabe um lugar com promoção da semana do...           1
# 140  @kl_inha ai é incrível tem 7000mah sendo que n...           1
# 141  @azksnialler não vai ter eu ganhando iphone 12...           0
# 142  foi no corre, investiu no melhor silicone, tir...           1
# 143  quem tem seu iate, sua ilha, os sonegadores de...           1
# 144  o bagui só custa 3x um iphone 12 pro max 512gb...           0
# 145  e eu lá tenho inveja do teu relacionamento per...           0
# 146  eu quero! clique no link para me ajudar a baix...           0
# 147  @bolsomito_2 eu também tenho dinheiro sobrando...           1
# 148  @googieweb não vai ter eu comprando meu iphone...           0
# 149  eu amo que a pessoa coloca na bio "só fotos co...           1
# 150     eu, quero um iphone 12 https://t.co/x4wrbwxrl7           1
# 151  @jnnietrust te indico iphone 12 mas um macbook...           1
# 152      ganhar um iphone 12.. https://t.co/r6vvbjnsg2           1
# 153  rt @atxnolasco: a dona maria vai ficar sem sac...           0
# 154  colocar silicone ou iphone 12 🤡🤡🤡 problema de ...           1
# 155  deus , tira de mim essa vontade de comprar um ...           1
# 156  @leonardotdleal e você esperava o que? um ipho...           0
# 157  a criatura quando tava comigo dizia que tava p...           1
# 158  @jonasdiandrade por esse preço eu compro um ip...           0
# 159                tem capas pra iphone do 8 até o 12.           0
# 160  @farialimaelevat pagaria a primeira parcela do...           1
# 161  [americanas] iphone 12 pro apple (128gb) grafi...           0
# 162  [18/03/2021 02:13:04] celle: amg vou te matar\...           0
# 163  [17/3 13:11] vitin: cê quer ganhar oque?\n[17/...           0
# 164  [17/3 12:35] mozin : tem samsung 1.500\n[17/3 ...           1
# 165  com 41k eu compro meu iphone 12 pro max e um c...           0
# 166  fiz um tik tok ao contrário do felps pq o que ...           1
# 167  o shake árabe me seguindo será que é minha cha...           1
# 168  acabei de assina a glambox tomara que venha um...           1
# 169  o menino comprou um iphone 12 e disse que cont...           1
# 170  alguma gabriela que tenha iphone 11 quer compr...           1
# 171  @jonasdiandrade o preço de um zenbook da pra c...           0
# 172  @gusoutulio eu n disse isso. eu disse que eu q...           1
# 173  @patrickpzt amigo vê se ela banca um iphone 12...           1
# 174  @delucaxgrey @mariacmts tem q ser seguidores r...           0
# 175  com o dinheiro que gasto nisso compro o iphone...           0
# 176  com o preço desse pc:\ncompro iphone 12 pro ma...           0
# 177  @g0nrafa não lembra... ontem fiquei tristy por...           0
# 178  velocidade do 5g no iphone 12 está muito longe...           1
# 179  deve vim o iphone 12 dentro só pode https://t....           0
# 180  a minha mae vai comprar o iphone 12 eu tbm quero😰           1
# 181  [3/18/21 06:41:01] rayane 👸🏻: bom diaaaaa, tia...           0
# 182  meu pai pegou iphone 12, agr q eu fico bnt nas...           1
# 183                       agr só volto p iphone 12 fds           1
# 184  não vai ter eu ganhando o iphone 12 pro https:...           0
# 185  a rosinha tirando selfie num iphone 12 pro e a...           1
# 186  iphone 12 lá fora tá 4 mil e pouco, aqui no br...           1
# 187  oq eu acho mais interessante é q eles sorteara...           1
# 188  rt @jkashabs: com essa chuvona em fortaleza, b...           1
# 189  @guzzvieira qualquer iphone 12 eu queria. um s...           1
# 190  @jnnietrust mas se vc tá precisando de um celu...           1
# 191  meu sonho trabalhar em um lugar que quando eu ...           1
# 192  +desde que a máscara dele caiu e perceberam o ...           0
# 193  41 mil reais compro um ipad pro uma apple penc...           0
# 194  @vihantuness é hoje que você sai de iphone 12 ...           1
# 195  xiangling (hutao de baixa renda) com a lanca d...           1
# 196  queria aparecer do nada com um iphone 12 pro m...           1
# 197           caiu o iphone 12 pro max em, quintouu 😂🍎           0
# 198  ganhei um iphone 12 no sorteio do insta e tô t...           1
# 199  @whatsanittx @davi_kiis tainá meu sonho é ter ...           1
# 200  @guirampinelli meu iphone 12 não vai se compra...           0
# 201  @henritothewild me lembro que há uns 12 anos a...           1
# 202  5g no iphone 12 está muito longe de toda a con...           1
# 203  @surtadonaxx @realgabrieladol entao me dá um i...           1
# 204  @eternizothurzin não vai ter eu ganhando um ip...           0
# 205  @depressivelaura se vê né lau, em 1950 as máqu...           0
# 206  projota, faça algo de bom com sua saída e me d...           1
# 207  @edsonmathison o iphone 12, ta mais de 14 mil ...           1
# 208  rt @a_pr1nces: @insta_acabar deve ser bom ser ...           1
# 209  tomara que sua inveja vire um iphone 12 pro ma...           1
# 210  em breve com meu iphone 12 amigxs 💅🏼🍷 https://...           1
# 211  rt @valdofml: @fierroallex @francshh o iphone ...           0
# 212          e eu que comprei um iphone 12 mini mesmo!           1
# 213  velocidade do 5g no iphone 12 está longe de to...           1
# 214  pensando em como ficar rica pra da o iphone 12...           0
# 215  minha gente os ovos de páscoa desse ano vem co...           0
# 216  mas hoje apenas se eu ganhasse um iphone 12 pr...           0
# 217  tô doida pra pegar o iphone 11 lilás, claro qu...           1
# 218  @yunorcrux ne, o que q custa comprar um iphone...           1
# 219  será q consigo me dar o iphone 12 de aniversár...           1
# 220  meu cunhado deu um iphone 12 de presente pra m...           1
# 221      eu quero um iphone 12 https://t.co/hcwl8aobpl           1
# 222  meu querido? nesse valor eu compro meu iphone ...           0
# 223  @jonasdiandrade se quebrar alguma coisa aí o c...           0
# 224   ateeee que enfim eu tô com meu iphone 12 pro! 😍😍           1
# 225  [18/03/2021 02:50:12] luciana: essa literalmen...           0
# 226  iphone 5 o melhor celular já feito na história...           1
# 227  bom dia vamos que vamos!\npai tá com estoque m...           0
# 228  #asus pode lançar zenfone 8 mini como alternat...           0
# 229  rt @yoyosantos6: dá vontade de me matar quando...           1
# 230  rt @wesley25493219: thaissa tá numa marra fudi...           1
# 231  virar amiga do filho do bolsonaro p pedir p el...           1
# 232  ꪶ→ pedido:boque de rosas vermelho e   um iphon...           0
# 233        @googieweb não vai ter eu ganhado iphone 12           0
# 234  @physicalnittx "oi fala la pa mamãe que eu mer...           1
# 235    magalu fazendo promoção de iphone 12 🤡🤡🤡🤡🤡🤡🤡🤡🤡🤡           0
# 236  iphone 12\ncadeira gamer 2k\nsetup que vale co...           1
# 237  @___amandagomes vou te dar um iphone 12 de pre...           1
# 238  minha mae ganhou logo um iphone 12 da empresa ...           1
# 239  @hazzplace não vai ter eu ganhando um iphone 1...           0
# 240  @sharshock @melanylolee shock fala pro meu pai...           0
# 241            @diegoxxsc preço de um iphone 12 mn pff           1
# 242  foi no corre, investiu no melhor silicone, tir...           1
# 243  rt @tharciosc: bom dia vamos que vamos!\npai t...           0
# 244  @jonasdiandrade o iphone 12 tá 7k isso aí tá i...           0
# 245  alguém sabe me dizer, qual dos ovos de páscoa ...           0
# 246  mn minha prima de 10 anos ganhou a poha de um ...           1
# 247  “essa mara aí é muito linda, parece até o ipho...           1
# 248  [17/3 03:28] gabi: o iphone é o 12\n[17/3 03:2...           0
# 249  tem um veio dando em cima de mim e perguntando...           0
# 250  rt @murilobusolin: sim, amigos, fui irônico co...           0
# 251  eu quero! clique no link para me ajudar a baix...           0
# 252  rasgou a camisa da lacoste, queimou minha tomm...           0
# 253  "kkkkk que coisa ruim eh da china"\nfilho da p...           0
# 254  projota se a sua saída me render um iphone 12 ...           0
# 255  minha mãe pegou meu celular e mandou msg pra m...           0
# 256  não vai ter eu comprando meu iphone 12 com meu...           0
# 257  com um desse eu compro macbook pro é um iphone...           0
# 258               apple pulará do iphone 12 para o 14?           0
# 259  41 mil reais = 1 iphone 12 + 1 macbook air 512...           0
# 260  eu quero! clique no link para me ajudar a baix...           0
# 261  @afectocline eu amei amg? eu rodei atrás dessa...           0
# 262  @googieweb nao vai ter eu com um iphone 12 ate...           0
# 263  @paulovieirareal @intrinseca o sucesso não che...           0
# 264  rt @jayamluby: faltou iphone 12 nessa caixa @c...           0
# 265  @wtfjaine @estebantavares imagina ser gado ass...           0
# 266  um notbook de 41mil ne kkkkkkk eu monto um pc ...           0
# 267  -ain quando eu tiver um iphone eu não quero ni...           0
# 268  rt @caldaxlu: *vem que é a boa*\ncapinhas para...           0
# 269                     @joy_trancoso só iphone 12 kkk           0
# 270  rt @celazevedos: alguém sabe me dizer como que...           0
# 271  bacana...\npelo preço desse note (no brasil), ...           0
# 272  @googieweb não vai ter eu ganhando um iphone 1...           0
# 273  bommmm dia 📢 projota eliminado 🙌🏽😁 e eu espero...           0
# 274  [magazine] iphone 12 pro max apple 256gb – azu...           0
# 275  @mauricioffernan amg a menina comprou um iphon...           0
# 276                         @willkaso vem um iphone 12           0
# 277                          @trajaza meu iphone 12 ❤️           0
# 278  verdade, por esse preço eu compro um iphone 12...           0
# 279  @azksnialler não vai ter eu ganhando um iphone...           0
# 280  por 41k eu compro um iphone 12, um macbook pro...           0
# 281  #256gb 🍎 versão #pro\n\niphone 12 pro apple 25...           0
# 282         @ruinvelez liv veio muito ai meu iphone 12           0
# 283  eu não tenho cartão de crédito... então se eu ...           0
# 284  eu cotando um iphone que não tenho dinheiro pr...           0
# 285  queria mesmo comprar o iphone 12 mas 1200€ em ...           0
# 286  @catboykenyan não vai ter eu ganhando um iphon...           0
# 287  nenhum sugar p ter somente meu “oi” e me dar u...           0
# 288  @googieweb não vai ter eu ganhando um iphone 1...           0
# 289  gente sério for fazer um fake faz bem feito......           0
# 290  à vista ou parcelado | iphone 12 está mais bar...           0
# 291  à vista ou parcelado | iphone 12 está mais bar...           0
# 292  alguem clica neste aqui plis\n\neu quero! cliq...           0
# 293                  @astefanibays chegou o iphone 12?           0
# 294  rt @crf_yza21: aqui esperando ele se declarar ...           0
# 295  quem ta afim de me dar um iphone 12 pro max 51...           0
# 296  entrei em um sorteio pra ganhar um iphone 12 n...           0
# 297  @jornaloglobo legal fera, agora é só esperar o...           0
# 298        @risk_protection comprar iphone 12 o galaxy           0
# 299  @santaroni7 @ceaga09 tem do iphone 12 pro max ...           0

# %%
test = pd.read_excel(filename, sheet_name = 'Teste')
test
# Out:
#                                                  Teste  categorias
# 0           iphone 12 mini é um iphone 5s, por fora né           1
# 1    eu sou trouxa ao ponto de ter esperança de gan...           0
# 2    ótima comparação, po. esse notebook custa apen...           1
# 3    @__karlamaiolly de brinde vem uma carne e um i...           1
# 4    eu quero! clique no link para me ajudar a baix...           0
# 5    odeio quando a minha net vai a baixo e tenho q...           0
# 6    só quero ganhar esse sorteio do iphone 12 do i...           0
# 7               só quero ganhar o sorteio do iphone 12           1
# 8    como comprar um iphone 12 vendendo peck do pez...           0
# 9    @rtkpedro @barbaaa se vc se refere ao iphone 1...           0
# 10   eu quero o iphone 12 pro max https://t.co/jovk...           1
# 11                 faculdade , carro ou iphone 12? 😂😂😂           1
# 12   só um milagre pra fazer eu ganhar o iphone 12 ...           0
# 13   @ttdaema @wtfisdudaa @ttdoiuis @pedrobarbosago...           1
# 14          nossa o iphone 12 ta 8 mil reais q absurdo           1
# 15   mia chefe lançou logo foi o iphone 12 pro max ...           1
# 16   deus, tira de mim essa vontade de comprar o ip...           1
# 17     @googieweb não vai ter eu ganhando um iphone 12           0
# 18   rt @vsampaiocrf: vendo\n\n iphone 12 pro\n iph...           0
# 19   o meu pai parte o iphone 12 e eu um iphone 11,...           1
# 20   @arrazzei @eanatani eu faria todos menos o vel...           0
# 21                  @camilito_d02 quero um iphone 12 🤩           1
# 22   @magazineluiza @samsungbrasil @canaltech lu, q...           0
# 23   ⁠essa vida de solteiro já me deu canseira\npre...           0
# 24                 só um iphone 12 me faria feliz hoje           1
# 25   definitivamente esse ovo valeu mais que um iph...           1
# 26   amada tu não estuda porque tu não quer, não po...           0
# 27   @ktchau95 kkkkkkkkk é o seguinte comédia, cola...           0
# 28   ansioso pra sexta feira porque vou ganhar meu ...           0
# 29   nossa ontem eu no centro da serra comendo um c...           0
# 30   apple começa a fabricar o iphone 12 na índia, ...           0
# 31   será que vale a pena pagar 12  mil em um iphon...           1
# 32   prefiro um iphone 12 pro max mesmo https://t.c...           0
# 33   rt @ezianrocha: era só um iphone 12 na minha vida           0
# 34   comprei o iphone 12 pro e agora não tenho dinh...           1
# 35   rt @ovarzeano: bacana...\npelo preço desse not...           0
# 36     @googieweb nao vai ter eu ganhando um iphone 12           0
# 37   @cadufaixa9 mais barato q o iphone 12 q vc dis...           0
# 38   por 31 mil reais eu compro um iphone 12 pro, u...           0
# 39   essa lista “vazada” acabou com o etapa kkkkkk ...           0
# 40                @alcrsk iphone 12 seu burgues safado           0
# 41   o preço dessa porra aí compro um mac top e um ...           0
# 42   iphone 12 9k \nzenbook preço de um onix \nfoda...           0
# 43   nós têm q ser igual a iphone 12\nse valoriza h...           1
# 44   @cellodosanjos @lilianmmachado @nathfinancas @...           0
# 45   agora só falta eu ganhar meu iphone 12 pra saí...           1
# 46   @jenbzr dnd amor, mas só uma dúvida vem carreg...           0
# 47           só faltava eu ganhar o bolão do iphone 12           0
# 48   vocês pediram e as cases para iphone 12 / mini...           0
# 49   @figueredoo03 se tiver um iphone 12 por uns 50...           0
# 50   eu nem ia saber usar esse troço, prefiro um ip...           1
# 51   droga samsung nao vai me mandar o iphone 12 ht...           0
# 52   @emanufsc @realgabrieladol um iphone 12 pro ma...           0
# 53   *vem que é a boa*\ncapinhas para iphone e sams...           0
# 54   @jvcaspary to c um iphone 12 lacrado aqui te e...           0
# 55   nao vai ter eu ganhando um iphone 12 https://t...           0
# 56   @canaltech vai revolucionar.\n\nesses tempos u...           1
# 57   @redliveofficial iphone 12 e deixa de brincade...           0
# 58   será que o iphone 12 vem fim de ano dessa vez ...           0
# 59   queria ter condições financeiras pra comprar u...           1
# 60   comida uma pandora,iphone 12 e uma twister🥰 ht...           0
# 61   @lburlet @thcardinelli nem iphone 12 salva vcs fi           1
# 62   não tenho nem 1 ano direito com esse iphone e ...           1
# 63   etapa dando iphone 12 pra melhor vídeo reagind...           0
# 64   "a asus pode lançar um pequeno zenfone 8 para ...           1
# 65                 para hoje, só queria um iphone 12 🤓           1
# 66   minha paciência ta igual ao meu iphone 12 não ...           1
# 67   mano que ódio desse celular, tipo é um iphone ...           0
# 68   @casgalisupreme só eu q percebi q o celular de...           0
# 69   eu e meu pai estavamos fazendo  as contas,  em...           1
# 70   @tuitalalari e eu espero ganhar um iphone 12 h...           0
# 71   rt @mabicalhof5: dayane somos sua forca vcs sã...           0
# 72   @denyberbett como que tu quer um iphone 12 ? k...           0
# 73   pensando em pegar o iphone 12 pro max nesse pr...           1
# 74     já pensou, ganhar um iphone 12?, pultz doideira           0
# 75   nao vai ter eu comprando um iphone 12 esse ano...           0
# 76                 ai já tô me vendo com meu iphone 12           1
# 77   @mephistosantos2 que vem com iphone 12 dentro,...           0
# 78   @alic3barros fisioterapeuta recém formada com ...           1
# 79   @charminglouie kakakak passo mal\nai nao vai t...           0
# 80   @bloodline91 eu amo demais, ele é maravilhoso,...           1
# 81   @jonasdiandrade com o preço disso da p comprar...           0
# 82   deus vc ta vendo minhas boas ações me de uma r...           0
# 83   @jvsena30 um iphone 12 de quebra , só pq cê tá...           0
# 84   rt @criaonipresente: muito fácil apoiar o isol...           0
# 85   @kauenasc_ iphone 12 tem quantos mah de bateria ?           1
# 86   @thomassantanas já pode pegar meus pra fazer a...           0
# 87   @stckwitme vem ai vc me pagando uma pizza luqu...           0
# 88   to começando a achar que tudo isso é uma grand...           0
# 89   com o preço dessa bosta, da pra comprar um mac...           0
# 90   foi no corre, investiu no melhor silicone, tir...           0
# 91   @pickmekj é difícil responder essa pergunta po...           0
# 92   boa noite. \nnão adianta vc ter iphone 12 se v...           0
# 93   nao meu shape tendo um iphone 12 pro e usando ...           1
# 94   um árabe me chamou na dm, se eu aparecer com u...           0
# 95   "nada mal p 12 anos"\nsim fi tu tem um iphone ...           0
# 96   quando eu for pai\n\nfumar: desde a maternidad...           0
# 97   @realgabrieladol @surtadonaxx e tu? vai me dar...           0
# 98                           quero um iphone 12 pro😭😭😭           1
# 99   motivos pra odiar o nct: comprei um iphone 12 ...           0
# 100  eu tinha acabado de pegar um iphone 12 e um pc...           1
# 101  a minha mãe vindo me mostrar iphone 12 pro max...           0
# 102               nossa eu acho o iphone 12 muito caro           1
# 103  pessoas normais:\npega meu celular aí na mesa ...           0
# 104  @trajaza minha mãe me dando o iphone 12 😹\nhtt...           0
# 105  o que adianta ter um iphone 12 de 32 giga? kkk...           1
# 106  como assim ela comprou um iphone 12 vendendo f...           0
# 107  @digiaimo_gi legal...\nme diz aí...\niphone 12...           1
# 108  a empresa do meu pai sempre da um celular p el...           1
# 109  @dayanestrap day com um celular barateiro sem ...           0
# 110  um iphone 12 pro seria tudo, mas aí que eu me ...           1
# 111  bah meu vcs deram dinheiro pra uma mina que te...           0
# 112  @48cps um iphone. estou entre 8, 11 e o 12. vo...           0
# 113  quem vai me dar um iphone 12 hoje hein https:/...           1
# 114  meu tio me mandou um link pra ganhar um iphone...           0
# 115  rt @mvrbraga: gente sério for fazer um fake fa...           0
# 116  eu qro um iphone 12 no meu niver 😢😢😢 tô qrndo ...           1
# 117  ê ê ê crlh onde tu comprou esse iphone 12 aí j...           0
# 118    @nanicv @assumps iphone 12 não é pra qlqr um né           1
# 119  alguém me dá capinha de iphone 12, de preferên...           0
# 120  não vai ter eu ganhando um iphone 12 esse ano ✊🏽😔           0
# 121  rt @eulaurii: [18/03/2021 02:13:04] celle: amg...           0
# 122  não vai ter eu ganhando um iphone 12 https://t...           0
# 123  @alvaropenerotti agora o próximo vai ser o iph...           0
# 124  rt @gizellybicalho: vou presentear 5 pessoas c...           0
# 125  @nezukosmtown sera que ele vai dar iphone 12 p...           0
# 126                           queria pega o iphone 12.           1
# 127  100 reais um ovo de páscoa ? vem um iphone 12 ...           0
# 128  @cyprianobibi eu não tenho mais rins, vendi na...           1
# 129  @emilyrxx1 @samsungbrasil eu te amo mais @sams...           0
# 130  thaissa tá numa marra fudida porcausa desse ip...           0
# 131  @azksnialler não vai ter eu ganhando um iphone...           0
# 132                                 queria o iphone 12           1
# 133  @leandroquesada segundo a maju coutinho dane-s...           0
# 134                  era só um iphone 12 na minha vida           1
# 135  a cliente com 17 anos fazendo lipoaspiração, v...           0
# 136  5g: samsung lidera ranking no android e iphone...           1
# 137  mas com o valor desse notebook, da pra comprar...           0
# 138  [17/3 12:38] mayara ponciano: eu dei um filho ...           0
# 139  eguas raul riquíssimo tem um iphone 6 e vcs ai...           0
# 140  @a_vic_silva ai amg, quero em... to precisando...           1
# 141  senhor tira essa vontade de comprar o iphone 1...           0
# 142                        @90sremus pede um iphone 12           0
# 143  rt @edupaivastore: 🤳🏽 iphone 12 apple 128gb pr...           0
# 144  @nascidopmorrer passa aqui que comprei já comp...           0
# 145  rt @stedile_mst: o governo biden, esse  obama ...           0
# 146  e sigo falando: pensem bem antes de ter um pet...           0
# 147  famoso é engraçado iphone 12 na mão e as fotos...           1
# 148  kkkkkkkk é mt gostoso, mas ai o pessoal espera...           1
# 149  @bakuglowing nao vai ter eu ganhando um iphone...           0
# 150  "celular que parece iphone 12 mini" https://t....           1
# 151  nego anda com samsung pocket no bolso e faz so...           0
# 152                  @luizopessoa um iphone 12 pró max           0
# 153  rt @omutanen: kkkkkk coitado do oliver nem sab...           0
# 154  @jnnietrust eu tenho um iphone 12 e amooooo tanto           1
# 155  não vai ter eu ganhando aquele iphone 12 branc...           0
# 156  @oyxmx tu acha melhor que iphone 12 ? to nessa...           0
# 157  olá! você já passou no meu canal do youtube ho...           0
# 158  iphone 12 pro de 128gb, de r$8.999,10 por r$7....           0
# 159  velocidade do 5g no iphone 12 está muito longe...           0
# 160  a menina ganhou so um iphone 12 e uma bolsa da...           0
# 161  @azksnialler não vai ter eu ganhado um iphone ...           0
# 162  até esperei uns dias pra ver se chegava mas to...           0
# 163  baixou❗ versão pro max #256gb 😱\n\niphone 12 p...           0
# 164  @bia3t guria ela é muito fofa. essas moedas se...           0
# 165  nunca vou conseguir fazer call aqui no tt pq e...           0
# 166           iphone 12 por 2 reais *google pesquisar*           0
# 167  trabalhar muito, até o final do ano que vem qu...           1
# 168  @jonasdiandrade quero o iphone , não vou pagar...           0
# 169  iphone 12 seu lindo, vai chegar quando em minh...           0
# 170  rt @canaltech: à vista ou parcelado | iphone 1...           0
# 171  esperando ganhar  meu iphone 12 do bolão https...           0
# 172  #promoção #oferta \n\n💵 por: r$ 8.781,99 \n🛒 l...           0
# 173     tô entre comprar outro iphone 11 ou pegar o 12           0
# 174           só queria comprar um iphone 12 \nmeodeos           0
# 175                       o pai tá de iphone 12💆🏻‍♂️🕺🏻           0
# 176  ''ei moça, esse ovo da páscoa aqui vem com um ...           0
# 177  até pensei em comprar um iphone 12 mas desisti...           1
# 178  @victor_barbosac credo,que professor caro!\nve...           0
# 179                  não vai ter eu ganhando iphone 12           0
# 180  rt @laraafilipaa: se eu juntasse todo dinheiro...           0
# 181  meu bebê agora se chama iphone 12 mini, foda-s...           0
# 182  um iphone 12 turbo pro tipo pacific maçã bué h...           0
# 183  @azksnialler não vai ter eu ganhando um iphone...           0
# 184  cismei com o iphone 12, era pra pegar no meu a...           1
# 185  vem a majucoutinho (essa mesma que recebe uns ...           0
# 186  fogo no colômbia gold, foto no iphone 12 🎶🔥\nm...           0
# 187  @vicio_bbb @jordaniagomes10 ninguém para avisa...           0
# 188  asus zenfone 8 mini: conhece as especificações...           0
# 189  fui ver o preço de ovo de páscoa para dar para...           0
# 190            pensando em comprar o iphone 12 pro max           1
# 191  meu celular tem dia que ta melhor que o iphone...           1
# 192  meu celular já está todo ferrado , quero o iph...           1
# 193  meu sonho antes de morrer é ganhar um iphone 1...           1
# 194  @ivanmateusla misericórdia... a qualidade do v...           1
# 195    @sooblist como vc quer terminar o ano iphone 12           1
# 196  pensando na loucura de parcelar um iphone 12 e...           1
# 197  asus zenfone 8 mini deve chegar com tela peque...           1
# 198  continuo querendo um iphone 12 pro max, algm? ...           1
# 199  queria pegar o iphone 12 pro max azul, mas tá ...           1
# 200            queria tanto um iphone 12, alguém? haha           1
# 201  como ter iphone 12 ganhando um salário mínimo\...           1
# 202         gente eu tô sentindo que meu iphone 12 vem           1
# 203  globo vc tem condição de colocar um iphone 12 ...           1
# 204  anderson comprou um iphone 12 por 500 reais lk...           1
# 205  ainda continuo querendo um iphone 12 https://t...           1
# 206  a mina prega o socialismo\nmas o pai anda de s...           1
# 207  marina critica os filtros pq nao usa uma camer...           1
# 208  @thamiresbarbbos parece até um iphone 12 pro, ...           1
# 209     eu acho que eu mereço um iphone 12, eu acho 🤭🤔           1
# 210  projota se fudeu, que eu ganhe o iphone 12 la ...           1
# 211  @ver_memes_ @alcrsk com o dinheiro de um iphon...           1
# 212  eu acho que day tá postando essas fotos de ens...           1
# 213  não sou fã do design do iphone 12, mas aquele ...           1
# 214  rt @jademilene11: não tenho nem 1 ano direito ...           1
# 215  @poeticr0ses isso e a camera de um iphone xr p...           1
# 216  a asus pode lançar um pequeno zenfone 8 para c...           1
# 217  e eu que sonhei que tinha ganhado um iphone 12...           1
# 218  e um aluno que hoje resolveu mostrar pros amig...           1
# 219  fico apavorado com quem tem iphone 8 plus, xs,...           1
# 220  uma hora dessa queria ta reclamando porque o i...           1
# 221  estava aqui pensando 🤔\n\n por que você quer c...           1
# 222  queria tanto que alguém chegasse com um iphone...           1
# 223  aham, com esse iphone 12, aliança mais grossa ...           1
# 224  projota saiu agora só falta eu ser sorteada pr...           1
# 225  @pamelavrsp se for o iphone 12 vou vender e co...           1
# 226  rt @kauabrrt: comprei o iphone 12 pro e agora ...           1
# 227      só queria ganhar um sorteio de um iphone 12 😢           1
# 228  adquiri um poderosíssimo iphone xs. murro no a...           1
# 229  como ter câmera de iphone 12 em pocket sansung...           1
# 230  @vandersonsiilva eu não compraria o 21 não, ac...           1
# 231  nem iphone 12, nem whisky 12 anos, nem carro z...           1
# 232  iplace me mandando e-mail sobre iphone 12........           1
# 233  @mii_silvaaa nss eu tb, só qria um iphone 12 😔...           1
# 234  rt @jocecrz: @jornaloglobo legal fera, agora é...           1
# 235  feio quero um iphone 12 😭🖐🏻 https://t.co/t1qvu...           1

# %% [markdown]
# ****

# %% [markdown]
# ___
# # <kbd><code style="font-family:Times New Roman;background:black;color:white">Classificador automático de sentimento</code></kbd>

# %% [markdown]
# <u>*Faça aqui uma descrição do seu produto e o que considerou como relevante ou não relevante na classificação dos tweets.*</u>
#
# *O produto escolhido foi o "Iphone 12". Classificamos como relevante todos os tweets que traria algum feedback, tanto positivo como negativo sobre o celular para que a empressa pudesse saber no que melhorar. Os tweets que falavam sobre aposta, sorteio ou comparaco com outros produtos que não são concorrentes foram classificados como irrelevantes.*
#
# ***

# %% [markdown]
# ___
# # <kbd><code style="font-family:Times New Roman;background:black;color:white">Montando um Classificador Naive-Bayes</code></kbd>
#
#
#
# <code style="font-family:Times New Roman">Considerando apenas as mensagens da planilha Treinamento, ensine  seu classificador.</code>

# %% [markdown]
# ****
# > <code style="background:darkblue;color:white">Limpeza de mensagens removendo os caracteres: enter, :, ", ', (, ), etc</code>

# %%
import re 

def cleanup(text):
    """ 
        Função de limpeza muito simples que troca alguns sinais básicos por espaços
    """
    import string
    punctuation = '[!-.:_?;]' # Note que os sinais [] são delimitadores de um conjunto.
    pattern = re.compile(punctuation)
    text_subbed = re.sub(pattern, '', text)
    return text_subbed

def clean_and_replace(list_to_clean):
    lista = []
    for e in list_to_clean:
        c = cleanup(e.lower())
        x = re.sub("@[A-Za-z0-9]+","",c)
        z = re.sub("https//tco/[A-Za-z0-9]+","",x)
        y = z.replace('\n', '').replace('  ', ' ')
        lista.append(y)
    return lista

# %% [markdown]
# <mark>*Texto total*</mark>

# %% [markdown]
# `lista_T` $\Rightarrow$ lista de tweets já limpos para treinamento

# %%
lista_T=[] 
lista_T = clean_and_replace(train.Treinamento)

print("O total de tweets para treinamento do classificador é:",len(lista_T))
# Out:
# O total de tweets para treinamento do classificador é: 300

# %% [markdown]
# `texto_total` $\Rightarrow$ *Reunindo todos os tweets em uma única variável de texto, separando cada palavra por um espaço*

# %%
texto_total=""
for e in lista_T:
    texto_total+= " " + e 
texto_total = cleanup(texto_total.lower())

# %% [markdown]
# <mark>*Texto relevante*</mark>

# %% [markdown]
# `relevante` $\Rightarrow$ *Separando os tweets de Treinamento da categoria Relevante*

# %%
filtra_linhas= train['categorias'] == 1
relevante= train.loc[filtra_linhas, :]

# %% [markdown]
# `Lista_T` $\Rightarrow$ *lista de tweets relevantes já limpos para treinamento*

# %%
lista_R=[]    
lista_R = clean_and_replace(relevante.Treinamento)

print('O total de tweets relevantes para treinamento do classificador é:',len(lista_R))
# Out:
# O total de tweets relevantes para treinamento do classificador é: 146

# %% [markdown]
# `texto_R` $\Rightarrow$ *Reunindo todos os tweets relevantes em uma única variável de texto, separando cada palavra por um espaço*

# %%
texto_R=""
for e in lista_R:
    texto_R+= " " + e 
texto_R = cleanup(texto_R.lower())

# %% [markdown]
# <mark>*Texto irrelevante*</mark>

# %% [markdown]
# `irrelevante` $\Rightarrow$ *Separando os tweets de Treinamento da categoria Irrelevante*

# %%
filtra_linhas_2 = train['categorias'] == 0
irrelevante= train.loc[filtra_linhas_2, :]

# %% [markdown]
# `Lista_I` $\Rightarrow$ *lista de tweets irrelevantes já limpos para treinamento*

# %%
lista_I=[]    
lista_I = clean_and_replace(irrelevante.Treinamento)

print('O total de tweets irrelevantes para treinamento do classificador é:',len(lista_I))
# Out:
# O total de tweets irrelevantes para treinamento do classificador é: 154

# %% [markdown]
# `texto_R` $\Rightarrow$ *Reunindo todos os tweets irrelevantes em uma única variável de texto, separando cada palavra por um espaço*

# %%
texto_I =""   
for e in lista_I:
    texto_I += " " + e 
texto_I = cleanup(texto_I.lower())

# %% [markdown]
# ****

# %% [markdown]
# ****
# > <code style="background:darkblue;color:white">Correção de espaços entre palavras e/ou emojis</code>

# %% [markdown]
# `texto` $\Rightarrow$ *texto contendo todas as palavras de treinamento após a correção de espaços*

# %%
texto_split_emoji = emoji.get_emoji_regexp().split(texto_total)
texto_split_whitespace = [substr.split() for substr in texto_split_emoji]
texto = functools.reduce(operator.concat, texto_split_whitespace)

# %% [markdown]
# `texto_relevante` $\Rightarrow$ *texto contendo apenas as palavras de treinamento do subconjunto relevante após a correção de espaços*

# %%
texto_split_emoji_R = emoji.get_emoji_regexp().split(texto_R)
texto_split_whitespace_R = [substr.split() for substr in texto_split_emoji_R ]
texto_relevante = functools.reduce(operator.concat, texto_split_whitespace_R)

# %% [markdown]
# `texto_irrelevante` $\Rightarrow$ *texto contendo apenas as palavras de treinamento do subconjunto irrelevante após a correção de espaços*

# %%
texto_split_emoji_I = emoji.get_emoji_regexp().split(texto_I)
texto_split_whitespace_I = [substr.split() for substr in texto_split_emoji_I ]
texto_irrelevante = functools.reduce(operator.concat, texto_split_whitespace_I)

# %% [markdown]
# ***

# %% [markdown]
# ****
# > <code style="background:darkblue;color:white">Suavização de Laplace</code>

# %% [markdown]
# <mark>*Cálculo das Probabilidades*</mark>

# %% [markdown]
# `prob_relevante` $\Rightarrow$ *Probabilidade do tweet ser relevante*

# %%
prob_relevante = len(lista_R)/len(lista_T)
print("A probabilidade do tweet ser relevante: P(R) =",prob_relevante)
# Out:
# A probabilidade do tweet ser relevante: P(R) = 0.4866666666666667

# %% [markdown]
# `prob_irrelevante` $\Rightarrow$ *Probabilidade do tweet ser irrelevante*

# %%
prob_irrelevante = len(lista_I)/len(lista_T)
print("A probabilidade do tweet ser irrelevante: P(I) =",prob_irrelevante)
# Out:
# A probabilidade do tweet ser irrelevante: P(I) = 0.5133333333333333

# %% [markdown]
# `total_texto_relevante` $\Rightarrow$ *Total de palavras no subconjunto relevante*

# %%
total_texto_relevante = len(texto_relevante)

# %% [markdown]
# `total_texto_irrelevante` $\Rightarrow$ *Total de palavras no subconjunto irrelevante*

# %%
total_texto_irrelevante = len(texto_irrelevante)

# %% [markdown]
# `vocabulario` $\Rightarrow$ *Permite obter o total de palavras diferentes no vocabulário de treinamento*

# %%
vocabulario = pd.Series(texto).drop_duplicates()

# %% [markdown]
# `total_por_palavra_R` $\Rightarrow$ *Contagem das palavras relevantes*

# %%
total_por_palavra_R = pd.Series(texto_relevante).value_counts()

# %% [markdown]
# `total_por_palavra_I` $\Rightarrow$ *Contagem das palavras irrelevantes*

# %%
total_por_palavra_I = pd.Series(texto_irrelevante).value_counts()

# %% [markdown]
# <mark>*Cálculo das probabilidades das palavras do vocabulário*</mark>

# %%
prob_palavras_R=[]
prob_palavras_I=[]

## Suavização de Laplace: Caso não tenha a palavra no vocabulario
# Probabilidade no conjunto relevante
laplace_R = 1/(total_texto_relevante + len(vocabulario))

#Probabilidade no conjunto irrelevante
laplace_I = 1/(total_texto_irrelevante + len(vocabulario))

#Percorre todo o vocabulario calculando as probabilidades tanto relevante como irrelevante
for palavra in vocabulario:
    if palavra in total_por_palavra_R:
        prob_r = (total_por_palavra_R[palavra] + 1)/(total_texto_relevante + len(vocabulario))
        prob_palavras_R.append(prob_r)
    else:
        prob_palavras_R.append(laplace_R)

    if palavra in total_por_palavra_I:
        prob_i = (total_por_palavra_I[palavra] + 1)/(total_texto_irrelevante + len(vocabulario))
        prob_palavras_I.append(prob_i)
    else:
        prob_palavras_I.append(laplace_I)

# %% [markdown]
# <mark>*Organização dos dados: dataframe com as palavras e probabilidades*</mark>

# %%
lista_prob = list(zip(vocabulario,prob_palavras_R,prob_palavras_I))
df_prob_aux = pd.DataFrame(lista_prob, columns = ['Palavra','P(palavra|Relevante)','P(palavra|Irrelevante)'])
df_prob = df_prob_aux.set_index('Palavra')
print(df_prob)
# Out:
#            P(palavra|Relevante)  P(palavra|Irrelevante)
# Palavra
# até                    0.001572                0.001515
# junho                  0.000524                0.000433
# compro                 0.000524                0.004113
# meu                    0.004979                0.005628
# iphone                 0.039570                0.031818
# ...                         ...                     ...
# esperar                0.000262                0.000433
# metade                 0.000262                0.000433
# financiar              0.000262                0.000433
# rlk                    0.000262                0.000433
# chama                  0.000262                0.000433
#
# [1461 rows x 2 columns]

# %% [markdown]
# ***

# %% [markdown]
# # <kbd><code style="font-family:Times New Roman;background:black;color:white">Verificando a performance do Classificador</code></kbd>
#
#
#
# <code style="font-family:Times New Roman">Agora você deve testar o seu classificador com a base de Testes.</code>

# %% [markdown]
# ****
# > <code style="background:darkblue;color:white">Limpeza de mensagens removendo os caracteres da base teste: enter, :, ", ', (, ), etc</code>

# %% [markdown]
# `lista_R_teste` $\Rightarrow$ *Limpeza da Lista para Teste de Tweets Relevantes*

# %%
filtra_linhas_teste= test['categorias'] == 1
relevante_teste= test.loc[filtra_linhas_teste, :]
lista_R_teste = []
lista_R_teste = clean_and_replace(relevante_teste.Teste)
print("O total de tweets relevantes usados no teste do classificador é :",len(lista_R_teste))
# Out:
# O total de tweets relevantes usados no teste do classificador é : 102

# %% [markdown]
# `lista_I_teste` $\Rightarrow$ *Limpeza da Lista para Teste de Tweets Irrelevantes*

# %%
filtra_linhas_teste_2 = test['categorias'] == 0
irrelevante_teste= test.loc[filtra_linhas_teste_2, :]
lista_I_teste=[]
lista_I_teste = clean_and_replace(irrelevante_teste.Teste)
print("O total de tweets irrelevantes usados no teste do classificador é :",len(lista_I_teste))
# Out:
# O total de tweets irrelevantes usados no teste do classificador é : 134

# %% [markdown]
# ***

# %% [markdown]
# ****
# > <code style="background:darkblue;color:white">Correção de espaços entre palavras e/ou emojis da base teste</code>

# %% [markdown]
# `lista_R` $\Rightarrow$ *lista de tweets relevantes já limpos para teste*

# %%
lista_R=[] 
for e in lista_R_teste:
    e = e.lower()
    texto_split_emoji_teste = emoji.get_emoji_regexp().split(e)
    texto_split_whitespace_teste = [substr.split() for substr in texto_split_emoji_teste]
    list_teste = functools.reduce(operator.concat, texto_split_whitespace_teste)
    lista_R.append(list_teste)

# %% [markdown]
# `lista_I` $\Rightarrow$ *lista de tweets irrelevantes já limpos para teste*

# %%
lista_I=[]
for e in lista_I_teste:
    e = e.lower()
    texto_split_emoji_teste = emoji.get_emoji_regexp().split(e)
    texto_split_whitespace_teste = [substr.split() for substr in texto_split_emoji_teste]
    list_teste = functools.reduce(operator.concat, texto_split_whitespace_teste)
    lista_I.append(list_teste)

# %% [markdown]
# ***

# %% [markdown]
# ****
# > <code style="background:darkblue;color:white">Testando cassificador</code>

# %% [markdown]
# <mark>*Teste dos tweets relevantes*</mark>

# %%
## Teste dos tweets relevantes
resultado_classificador_R = []
hipotese_melhoria = []

k = 0

#probabilidade da mensagem ser relevante/irrelevante
prob_msg_relevante = 1      
prob_msg_irrelevante = 1

#Contagem de mensagens relevantes/irrelevantes
relevantes_corretas = 0
falso_negativo = 0

while k < len(lista_R):
    for palavra in lista_R[k]:
        #Produto das probabilidades de cada palavra do tweet
        #Caso a palavra faça parte do vocabulário de Treinamento
        try:
            prob_palavra_dado_r = df_prob.loc[palavra]['P(palavra|Relevante)']
            prob_palavra_dado_i = df_prob.loc[palavra]['P(palavra|Irrelevante)']
                
        #Exceção: caso a palavra não conste no vocabulário obtido no Treinamento, deve ter sua prob = 1/(total de palavras + vocabulario)
        except:
            prob_palavra_dado_r = laplace_R
            prob_palavra_dado_i = laplace_I

        prob_msg_relevante = prob_msg_relevante*prob_palavra_dado_r
        prob_msg_irrelevante = prob_msg_irrelevante*prob_palavra_dado_i
        
    #Após as multiplicações das probabilidades das palavras, devemos multiplicar por P(Relevante) e P(Irrelevante)
    prob_msg_relevante = prob_msg_relevante*prob_relevante
    prob_msg_irrelevante = prob_msg_irrelevante*prob_irrelevante
    
    #Classificação: se P(tweet|R).P(R) > P(tweet|I).P(I), então classificamos como Relevante.
    if prob_msg_relevante > prob_msg_irrelevante:
        relevantes_corretas+=1
        resultado_classificador_R.append("Relevante")
    else:
        falso_negativo+=1
        resultado_classificador_R.append("Irrelevante")
    
    hipotese_melhoria.append(prob_msg_relevante/prob_msg_irrelevante)
    
    k+=1
    #Após classificar um tweet, as probabilidades devemos reatribuir 1 para as probabilidades
    prob_msg_relevante = 1
    prob_msg_irrelevante = 1

print("O teste apresentou ", relevantes_corretas, 
      " mensagens relevantes corretamente identificadas e ", falso_negativo, " falso(s) negativo(s)")
# Out:
# O teste apresentou  74  mensagens relevantes corretamente identificadas e  28  falso(s) negativo(s)

# %% [markdown]
# <mark>*Teste dos tweets irrelevantes*</mark>

# %%
## Teste dos tweets Irrelevantes
resultado_classificador_I = []

k = 0

#probabilidade da mensagem ser relevante/irrelevante
prob_msg_relevante = 1      
prob_msg_irrelevante = 1

#Contagem de mensagens relevantes/irrelevantes
irrelevantes_corretas = 0
falso_positivo = 0

while k < len(lista_I):
    for palavra in lista_I[k]:
        #Produto das probabilidades de cada palavra do tweet
        #Caso a palavra faça parte do vocabulário de Treinamento
        try:
            prob_palavra_dado_r = df_prob.loc[palavra]['P(palavra|Relevante)']
            prob_palavra_dado_i = df_prob.loc[palavra]['P(palavra|Irrelevante)']
                
        #Exceção: caso a palavra não conste no vocabulário obtido no Treinamento, deve ter sua prob = 1/(total de palavras + vocabulario)
        except:
            prob_palavra_dado_r = laplace_R
            prob_palavra_dado_i = laplace_I

        prob_msg_relevante = prob_msg_relevante*prob_palavra_dado_r
        prob_msg_irrelevante = prob_msg_irrelevante*prob_palavra_dado_i
        
    #Após as multiplicações das probabilidades das palavras, devemos multiplicar por P(Relevante) e P(Irrelevante)
    prob_msg_relevante = prob_msg_relevante*prob_relevante
    prob_msg_irrelevante = prob_msg_irrelevante*prob_irrelevante
    
    #Classificação: se P(tweet|R).P(R) > P(tweet|I).P(I), então classificamos como Relevante.
    if prob_msg_relevante > prob_msg_irrelevante:
        falso_positivo+=1
        resultado_classificador_I.append("Relevante")
    else:
        irrelevantes_corretas+=1
        resultado_classificador_I.append("Irrelevante")
    
    hipotese_melhoria.append(prob_msg_relevante/prob_msg_irrelevante)
    
    k+=1
    #Após classificar um tweet, as probabilidades devemos reatribuir 1 para as probabilidades
    prob_msg_relevante = 1
    prob_msg_irrelevante = 1

print("O teste apresentou ", irrelevantes_corretas, 
      " mensagens irrelevantes corretamente identificadas e ", falso_positivo, " falso(s) positivo(s)")
# Out:
# O teste apresentou  52  mensagens irrelevantes corretamente identificadas e  82  falso(s) positivo(s)

# %% [markdown]
# <mark>*Cálculo das porcentagens do Classificador*</mark>

# %% [raw]
# ✓ Porcentagem de verdadeiros positivos (mensagens relevantes e que são classificadas como relevantes)
# ✓ Porcentagem de falsos positivos (mensagens irrelevantes e que são classificadas como relevantes)
# ✓ Porcentagem de verdadeiros negativos (mensagens irrelevantes e que são classificadas como irrelevantes)
# ✓ Porcentagem de falsos negativos (mensagens relevantes e que são classificadas como irrelevantes)

# %%
total_teste = len(lista_R) + len(lista_I)
porc_positivos_corretos = relevantes_corretas/total_teste
porc_negativos_corretos = irrelevantes_corretas/total_teste
porc_falso_negativo = falso_negativo/total_teste
porc_falso_positivo = falso_positivo/total_teste

print('{:.1%}'.format(porc_positivos_corretos), "de Verdadeiros Positivos")
print('{:.1%}'.format(porc_negativos_corretos), "de Verdadeiros Negativos")
print('{:.1%}'.format(porc_falso_negativo), "de Falsos Negativos")
print('{:.1%}'.format(porc_falso_positivo), "de Falsos Positivos")
# Out:
# 31.4% de Verdadeiros Positivos
# 22.0% de Verdadeiros Negativos
# 11.9% de Falsos Negativos
# 34.7% de Falsos Positivos

# %% [markdown]
# ***

# %% [markdown]
# ___
# # <kbd><code style="font-family:Times New Roman;background:black;color:white">Concluindo</code></kbd>

# %% [markdown]
# *Neste artigo, tentamos fazer uma análise de sentimento sobre a opinião do público em geral sobre o iPhone 12. Para obter essas informações, coletamos tweets que mencionavam o produto e para obter um resultado mais específico, decidimos nos basear na pergunta: Quais recursos poderíamos melhorar para o lançamento do próximo iPhone?*
#
# *De acordo com o problema, esse banco de dados pode ser dividido em duas categorias: relevante e irrelevante. Os tweets relevantes incluem aqueles com feedback que irão aumentar os pontos fortes e fracos do produto; aqueles que não respondem às nossas perguntas são irrelevantes. Este processo é feito com base em treinamento e teste. Iniciamos a divisão baseando-se na base de treinamento, na qual já tínhamos divisões e podíamos compilar os cálculos a partir delas, portanto não poderíamos usar o classificador para gerar amostras na base de treinamento,que afetaria nossos resultados, pois retiramos o valores de la  para treinar o programa.*
#
# *Nosso classificador teve uma acurácia de 53,4%, ou seja, a classe que nós colocamos os tweets foram iguais a categoria que o programa colocou em 53,4% dos casos.*
#
# *Possibilidade de Aperfeiçoamento: De acordo com o texto 'Naive Bayes and Text Classification I', de Sebastian Raschka, incluído nas referências do projeto, poderíamos remover palavras que são muito frequentes mas não são informativas (chamadas Stop Words e descritas no item 3.2.1 na página 14).*
#
# *Naive Bayes pode ser usado em várias ocasiões, não apenas para classificar tweets, mas também para avaliar a probabilidade de eventos. Um exemplo de aplicação muito comum é identificar se um determinado e-mail é spam ou não. Outro exemplo é uma instituição financeira que usa software de mineração de dados para identificar se seus clientes em potencial estão em risco “baixo”, “médio” ou “alto” para conceder financiamento imobiliário.*

# %% [markdown]
# ___
# # <kbd><code style="font-family:Times New Roman;background:black;color:white"> Qualidade do Classificador a partir de novas separações dos tweets entre Treinamento e Teste</code></kbd>

# %%
def embaralhar():
    relacao_colunas = {'Teste':'Treinamento'}
    df_teste_treinamento = pd.concat([train, test.rename(columns=relacao_colunas)])
    df_embaralhado=df_teste_treinamento.sample(frac=1).reset_index(drop=True)
    return df_embaralhado

# %%
lista_acertos_relevantes=[]
lista_acertos_irrelevantes=[]

# %%
#Essa célula pode levar 2 minutos para carregar
for j in range(100):
    train=embaralhar().iloc[:300,:]
    test=embaralhar().iloc[300:,:]
    
    lista_T=[] 
    lista_T = clean_and_replace(train.Treinamento)
    texto_total=""
    for e in lista_T:
        texto_total+= " " + e 
    texto_total = cleanup(texto_total.lower())
    filtra_linhas= train['categorias'] == 1
    relevante= train.loc[filtra_linhas, :]
    lista_R=[]    
    lista_R = clean_and_replace(relevante.Treinamento)
    texto_R=""
    for e in lista_R:
        texto_R+= " " + e 
    texto_R = cleanup(texto_R.lower())
    filtra_linhas_2 = train['categorias'] == 0
    irrelevante= train.loc[filtra_linhas_2, :]
    lista_I=[]    
    lista_I = clean_and_replace(irrelevante.Treinamento)
    texto_I =""   
    for e in lista_I:
        texto_I += " " + e 
    texto_I = cleanup(texto_I.lower())
    texto_split_emoji = emoji.get_emoji_regexp().split(texto_total)
    texto_split_whitespace = [substr.split() for substr in texto_split_emoji]
    texto = functools.reduce(operator.concat, texto_split_whitespace)
    texto_split_emoji_R = emoji.get_emoji_regexp().split(texto_R)
    texto_split_whitespace_R = [substr.split() for substr in texto_split_emoji_R ]
    texto_relevante = functools.reduce(operator.concat, texto_split_whitespace_R)
    texto_split_emoji_I = emoji.get_emoji_regexp().split(texto_I)
    texto_split_whitespace_I = [substr.split() for substr in texto_split_emoji_I ]
    texto_irrelevante = functools.reduce(operator.concat, texto_split_whitespace_I)
    prob_relevante = len(lista_R)/len(lista_T)
    prob_irrelevante = len(lista_I)/len(lista_T)
    total_texto_relevante = len(texto_relevante)
    total_texto_irrelevante = len(texto_irrelevante)
    vocabulario = pd.Series(texto).drop_duplicates()
    total_por_palavra_R = pd.Series(texto_relevante).value_counts()
    total_por_palavra_I = pd.Series(texto_irrelevante).value_counts()
    prob_palavras_R=[]
    prob_palavras_I=[]

    ## Suavização de Laplace: Caso não tenha a palavra no vocabulario
    # Probabilidade no conjunto relevante
    laplace_R = 1/(total_texto_relevante + len(vocabulario))

    #Probabilidade no conjunto irrelevante
    laplace_I = 1/(total_texto_irrelevante + len(vocabulario))

    #Percorre todo o vocabulario calculando as probabilidades tanto relevante como irrelevante
    for palavra in vocabulario:
        if palavra in total_por_palavra_R:
            prob_r = (total_por_palavra_R[palavra] + 1)/(total_texto_relevante + len(vocabulario))
            prob_palavras_R.append(prob_r)
        else:
            prob_palavras_R.append(laplace_R)

        if palavra in total_por_palavra_I:
            prob_i = (total_por_palavra_I[palavra] + 1)/(total_texto_irrelevante + len(vocabulario))
            prob_palavras_I.append(prob_i)
        else:
            prob_palavras_I.append(laplace_I)
    lista_prob = list(zip(vocabulario,prob_palavras_R,prob_palavras_I))
    df_prob_aux = pd.DataFrame(lista_prob, columns = ['Palavra','P(palavra|Relevante)','P(palavra|Irrelevante)'])
    df_prob = df_prob_aux.set_index('Palavra')
    filtra_linhas_teste= test['categorias'] == 1
    relevante_teste= test.loc[filtra_linhas_teste, :]
    lista_R_teste = []
    lista_R_teste = clean_and_replace(relevante_teste.Treinamento)
    filtra_linhas_teste_2 = test['categorias'] == 0
    irrelevante_teste= test.loc[filtra_linhas_teste_2, :]
    lista_I_teste=[]
    lista_I_teste = clean_and_replace(irrelevante_teste.Treinamento)
    lista_R=[] 
    for e in lista_R_teste:
        e = e.lower()
        texto_split_emoji_teste = emoji.get_emoji_regexp().split(e)
        texto_split_whitespace_teste = [substr.split() for substr in texto_split_emoji_teste]
        list_teste = functools.reduce(operator.concat, texto_split_whitespace_teste)
        lista_R.append(list_teste)
    lista_I=[]
    for e in lista_I_teste:
        e = e.lower()
        texto_split_emoji_teste = emoji.get_emoji_regexp().split(e)
        texto_split_whitespace_teste = [substr.split() for substr in texto_split_emoji_teste]
        list_teste = functools.reduce(operator.concat, texto_split_whitespace_teste)
        lista_I.append(list_teste)
    
    ## Teste dos tweets relevantes
    resultado_classificador_R = []
    hipotese_melhoria = []
    k = 0

    #probabilidade da mensagem ser relevante/irrelevante
    prob_msg_relevante = 1      
    prob_msg_irrelevante = 1

    #Contagem de mensagens relevantes/irrelevantes
    relevantes_corretas = 0
    falso_negativo = 0

    while k < len(lista_R):
        for palavra in lista_R[k]:
            #Produto das probabilidades de cada palavra do tweet
            #Caso a palavra faça parte do vocabulário de Treinamento
            try:
                prob_palavra_dado_r = df_prob.loc[palavra]['P(palavra|Relevante)']
                prob_palavra_dado_i = df_prob.loc[palavra]['P(palavra|Irrelevante)']

            #Exceção: caso a palavra não conste no vocabulário obtido no Treinamento, deve ter sua prob = 1/(total de palavras + vocabulario)
            except:
                prob_palavra_dado_r = laplace_R
                prob_palavra_dado_i = laplace_I

            prob_msg_relevante = prob_msg_relevante*prob_palavra_dado_r
            prob_msg_irrelevante = prob_msg_irrelevante*prob_palavra_dado_i

        #Após as multiplicações das probabilidades das palavras, devemos multiplicar por P(Relevante) e P(Irrelevante)
        prob_msg_relevante = prob_msg_relevante*prob_relevante
        prob_msg_irrelevante = prob_msg_irrelevante*prob_irrelevante

        #Classificação: se P(tweet|R).P(R) > P(tweet|I).P(I), então classificamos como Relevante.
        if prob_msg_relevante > prob_msg_irrelevante:
            relevantes_corretas+=1
            resultado_classificador_R.append("Relevante")
        else:
            falso_negativo+=1
            resultado_classificador_R.append("Irrelevante")

        hipotese_melhoria.append(prob_msg_relevante/prob_msg_irrelevante)

        k+=1
        #Após classificar um tweet, as probabilidades devemos reatribuir 1 para as probabilidades
        prob_msg_relevante = 1
        prob_msg_irrelevante = 1
        
     ## Teste dos tweets Irrelevantes
    resultado_classificador_I = []

    k = 0

    #probabilidade da mensagem ser relevante/irrelevante
    prob_msg_relevante = 1      
    prob_msg_irrelevante = 1

    #Contagem de mensagens relevantes/irrelevantes
    irrelevantes_corretas = 0
    falso_positivo = 0

    while k < len(lista_I):
        for palavra in lista_I[k]:
            #Produto das probabilidades de cada palavra do tweet
            #Caso a palavra faça parte do vocabulário de Treinamento
            try:
                prob_palavra_dado_r = df_prob.loc[palavra]['P(palavra|Relevante)']
                prob_palavra_dado_i = df_prob.loc[palavra]['P(palavra|Irrelevante)']

            #Exceção: caso a palavra não conste no vocabulário obtido no Treinamento, deve ter sua prob = 1/(total de palavras + vocabulario)
            except:
                prob_palavra_dado_r = laplace_R
                prob_palavra_dado_i = laplace_I

            prob_msg_relevante = prob_msg_relevante*prob_palavra_dado_r
            prob_msg_irrelevante = prob_msg_irrelevante*prob_palavra_dado_i

        #Após as multiplicações das probabilidades das palavras, devemos multiplicar por P(Relevante) e P(Irrelevante)
        prob_msg_relevante = prob_msg_relevante*prob_relevante
        prob_msg_irrelevante = prob_msg_irrelevante*prob_irrelevante

        #Classificação: se P(tweet|R).P(R) > P(tweet|I).P(I), então classificamos como Relevante.
        if prob_msg_relevante > prob_msg_irrelevante:
            falso_positivo+=1
            resultado_classificador_I.append("Relevante")
        else:
            irrelevantes_corretas+=1
            resultado_classificador_I.append("Irrelevante")

        hipotese_melhoria.append(prob_msg_relevante/prob_msg_irrelevante)

        k+=1
        #Após classificar um tweet, as probabilidades devemos reatribuir 1 para as probabilidades
        prob_msg_relevante = 1
        prob_msg_irrelevante = 1
        
    total_teste = len(lista_R) + len(lista_I)
    porc_positivos_corretos = relevantes_corretas/total_teste
    porc_negativos_corretos = irrelevantes_corretas/total_teste
    porc_falso_negativo = falso_negativo/total_teste
    porc_falso_positivo = falso_positivo/total_teste
    
    print("______________________________________________________")
    print('{:.1%}'.format(porc_positivos_corretos), "de Verdadeiros Positivos")
    print('{:.1%}'.format(porc_negativos_corretos), "de Verdadeiros Negativos")
    print('{:.1%}'.format(porc_falso_negativo), "de Falsos Negativos")
    print('{:.1%}'.format(porc_falso_positivo), "de Falsos Positivos")
    print("______________________________________________________")
# Out:
# ______________________________________________________
# 87.3% de Verdadeiros Positivos
# 12.7% de Verdadeiros Negativos
# 0.0% de Falsos Negativos
# 0.0% de Falsos Positivos
# ______________________________________________________
# ______________________________________________________
# 86.0% de Verdadeiros Positivos
# 14.0% de Verdadeiros Negativos
# 0.0% de Falsos Negativos
# 0.0% de Falsos Positivos
# ______________________________________________________
# ______________________________________________________
# 84.7% de Verdadeiros Positivos
# 15.3% de Verdadeiros Negativos
# 0.0% de Falsos Negativos
# 0.0% de Falsos Positivos
# ______________________________________________________
# ______________________________________________________
# 89.0% de Verdadeiros Positivos
# 11.0% de Verdadeiros Negativos
# 0.0% de Falsos Negativos
# 0.0% de Falsos Positivos
# ______________________________________________________
# ______________________________________________________
# 89.0% de Verdadeiros Positivos
# 11.0% de Verdadeiros Negativos
# 0.0% de Falsos Negativos
# 0.0% de Falsos Positivos
# ______________________________________________________
# ______________________________________________________
# 91.1% de Verdadeiros Positivos
# 8.9% de Verdadeiros Negativos
# 0.0% de Falsos Negativos
# 0.0% de Falsos Positivos
# ______________________________________________________
# ______________________________________________________
# 89.0% de Verdadeiros Positivos
# 11.0% de Verdadeiros Negativos
# 0.0% de Falsos Negativos
# 0.0% de Falsos Positivos
# ______________________________________________________
# ______________________________________________________
# 91.9% de Verdadeiros Positivos
# 8.1% de Verdadeiros Negativos
# 0.0% de Falsos Negativos
# 0.0% de Falsos Positivos
# ______________________________________________________
# ______________________________________________________
# 92.8% de Verdadeiros Positivos
# 7.2% de Verdadeiros Negativos
# 0.0% de Falsos Negativos
# 0.0% de Falsos Positivos
# ______________________________________________________
# ______________________________________________________
# 91.9% de Verdadeiros Positivos
# 8.1% de Verdadeiros Negativos
# 0.0% de Falsos Negativos
# 0.0% de Falsos Positivos
# ______________________________________________________
# ______________________________________________________
# 87.7% de Verdadeiros Positivos
# 12.3% de Verdadeiros Negativos
# 0.0% de Falsos Negativos
# 0.0% de Falsos Positivos
# ______________________________________________________
# ______________________________________________________
# 90.7% de Verdadeiros Positivos
# 9.3% de Verdadeiros Negativos
# 0.0% de Falsos Negativos
# 0.0% de Falsos Positivos
# ______________________________________________________
# ______________________________________________________
# 88.6% de Verdadeiros Positivos
# 11.4% de Verdadeiros Negativos
# 0.0% de Falsos Negativos
# 0.0% de Falsos Positivos
# ______________________________________________________
# ______________________________________________________
# 86.4% de Verdadeiros Positivos
# 13.6% de Verdadeiros Negativos
# 0.0% de Falsos Negativos
# 0.0% de Falsos Positivos
# ______________________________________________________
# ______________________________________________________
# 89.4% de Verdadeiros Positivos
# 10.6% de Verdadeiros Negativos
# 0.0% de Falsos Negativos
# 0.0% de Falsos Positivos
# ______________________________________________________
# ______________________________________________________
# 86.9% de Verdadeiros Positivos
# 13.1% de Verdadeiros Negativos
# 0.0% de Falsos Negativos
# 0.0% de Falsos Positivos
# ______________________________________________________
# ______________________________________________________
# 88.1% de Verdadeiros Positivos
# 11.9% de Verdadeiros Negativos
# 0.0% de Falsos Negativos
# 0.0% de Falsos Positivos
# ______________________________________________________
# ______________________________________________________
# 89.4% de Verdadeiros Positivos
# 10.6% de Verdadeiros Negativos
# 0.0% de Falsos Negativos
# 0.0% de Falsos Positivos
# ______________________________________________________
# ______________________________________________________
# 88.6% de Verdadeiros Positivos
# 11.4% de Verdadeiros Negativos
# 0.0% de Falsos Negativos
# 0.0% de Falsos Positivos
# ______________________________________________________
# ______________________________________________________
# 89.4% de Verdadeiros Positivos
# 10.6% de Verdadeiros Negativos
# 0.0% de Falsos Negativos
# 0.0% de Falsos Positivos
# ______________________________________________________
# ______________________________________________________
# 88.1% de Verdadeiros Positivos
# 11.9% de Verdadeiros Negativos
# 0.0% de Falsos Negativos
# 0.0% de Falsos Positivos
# ______________________________________________________
# ______________________________________________________
# 89.4% de Verdadeiros Positivos
# 10.6% de Verdadeiros Negativos
# 0.0% de Falsos Negativos
# 0.0% de Falsos Positivos
# ______________________________________________________
# ______________________________________________________
# 88.6% de Verdadeiros Positivos
# 11.4% de Verdadeiros Negativos
# 0.0% de Falsos Negativos
# 0.0% de Falsos Positivos
# ______________________________________________________
# ______________________________________________________
# 91.1% de Verdadeiros Positivos
# 8.9% de Verdadeiros Negativos
# 0.0% de Falsos Negativos
# 0.0% de Falsos Positivos
# ______________________________________________________
# ______________________________________________________
# 90.7% de Verdadeiros Positivos
# 9.3% de Verdadeiros Negativos
# 0.0% de Falsos Negativos
# 0.0% de Falsos Positivos
# ______________________________________________________
# ______________________________________________________
# 88.1% de Verdadeiros Positivos
# 11.9% de Verdadeiros Negativos
# 0.0% de Falsos Negativos
# 0.0% de Falsos Positivos
# ______________________________________________________
# ______________________________________________________
# 88.6% de Verdadeiros Positivos
# 11.4% de Verdadeiros Negativos
# 0.0% de Falsos Negativos
# 0.0% de Falsos Positivos
# ______________________________________________________
# ______________________________________________________
# 89.0% de Verdadeiros Positivos
# 11.0% de Verdadeiros Negativos
# 0.0% de Falsos Negativos
# 0.0% de Falsos Positivos
# ______________________________________________________
# ______________________________________________________
# 90.3% de Verdadeiros Positivos
# 9.7% de Verdadeiros Negativos
# 0.0% de Falsos Negativos
# 0.0% de Falsos Positivos
# ______________________________________________________
# ______________________________________________________
# 89.8% de Verdadeiros Positivos
# 10.2% de Verdadeiros Negativos
# 0.0% de Falsos Negativos
# 0.0% de Falsos Positivos
# ______________________________________________________
# ______________________________________________________
# 90.3% de Verdadeiros Positivos
# 9.7% de Verdadeiros Negativos
# 0.0% de Falsos Negativos
# 0.0% de Falsos Positivos
# ______________________________________________________
# ______________________________________________________
# 90.7% de Verdadeiros Positivos
# 9.3% de Verdadeiros Negativos
# 0.0% de Falsos Negativos
# 0.0% de Falsos Positivos
# ______________________________________________________
# ______________________________________________________
# 87.3% de Verdadeiros Positivos
# 12.7% de Verdadeiros Negativos
# 0.0% de Falsos Negativos
# 0.0% de Falsos Positivos
# ______________________________________________________
# ______________________________________________________
# 89.0% de Verdadeiros Positivos
# 11.0% de Verdadeiros Negativos
# 0.0% de Falsos Negativos
# 0.0% de Falsos Positivos
# ______________________________________________________
# ______________________________________________________
# 86.4% de Verdadeiros Positivos
# 13.6% de Verdadeiros Negativos
# 0.0% de Falsos Negativos
# 0.0% de Falsos Positivos
# ______________________________________________________
# ______________________________________________________
# 86.9% de Verdadeiros Positivos
# 13.1% de Verdadeiros Negativos
# 0.0% de Falsos Negativos
# 0.0% de Falsos Positivos
# ______________________________________________________
# ______________________________________________________
# 85.2% de Verdadeiros Positivos
# 14.8% de Verdadeiros Negativos
# 0.0% de Falsos Negativos
# 0.0% de Falsos Positivos
# ______________________________________________________
# ______________________________________________________
# 86.0% de Verdadeiros Positivos
# 14.0% de Verdadeiros Negativos
# 0.0% de Falsos Negativos
# 0.0% de Falsos Positivos
# ______________________________________________________
# ______________________________________________________
# 87.3% de Verdadeiros Positivos
# 12.7% de Verdadeiros Negativos
# 0.0% de Falsos Negativos
# 0.0% de Falsos Positivos
# ______________________________________________________
# ______________________________________________________
# 84.3% de Verdadeiros Positivos
# 15.7% de Verdadeiros Negativos
# 0.0% de Falsos Negativos
# 0.0% de Falsos Positivos
# ______________________________________________________
# ______________________________________________________
# 85.2% de Verdadeiros Positivos
# 14.8% de Verdadeiros Negativos
# 0.0% de Falsos Negativos
# 0.0% de Falsos Positivos
# ______________________________________________________
# ______________________________________________________
# 85.6% de Verdadeiros Positivos
# 14.4% de Verdadeiros Negativos
# 0.0% de Falsos Negativos
# 0.0% de Falsos Positivos
# ______________________________________________________
# ______________________________________________________
# 84.3% de Verdadeiros Positivos
# 15.7% de Verdadeiros Negativos
# 0.0% de Falsos Negativos
# 0.0% de Falsos Positivos
# ______________________________________________________
# ______________________________________________________
# 86.0% de Verdadeiros Positivos
# 14.0% de Verdadeiros Negativos
# 0.0% de Falsos Negativos
# 0.0% de Falsos Positivos
# ______________________________________________________
# ______________________________________________________
# 88.6% de Verdadeiros Positivos
# 11.4% de Verdadeiros Negativos
# 0.0% de Falsos Negativos
# 0.0% de Falsos Positivos
# ______________________________________________________
# ______________________________________________________
# 87.3% de Verdadeiros Positivos
# 12.7% de Verdadeiros Negativos
# 0.0% de Falsos Negativos
# 0.0% de Falsos Positivos
# ______________________________________________________
# ______________________________________________________
# 86.9% de Verdadeiros Positivos
# 13.1% de Verdadeiros Negativos
# 0.0% de Falsos Negativos
# 0.0% de Falsos Positivos
# ______________________________________________________
# ______________________________________________________
# 84.7% de Verdadeiros Positivos
# 15.3% de Verdadeiros Negativos
# 0.0% de Falsos Negativos
# 0.0% de Falsos Positivos
# ______________________________________________________
# ______________________________________________________
# 84.3% de Verdadeiros Positivos
# 15.7% de Verdadeiros Negativos
# 0.0% de Falsos Negativos
# 0.0% de Falsos Positivos
# ______________________________________________________
# ______________________________________________________
# 85.6% de Verdadeiros Positivos
# 14.4% de Verdadeiros Negativos
# 0.0% de Falsos Negativos
# 0.0% de Falsos Positivos
# ______________________________________________________
# ______________________________________________________
# 83.9% de Verdadeiros Positivos
# 16.1% de Verdadeiros Negativos
# 0.0% de Falsos Negativos
# 0.0% de Falsos Positivos
# ______________________________________________________
# ______________________________________________________
# 83.9% de Verdadeiros Positivos
# 16.1% de Verdadeiros Negativos
# 0.0% de Falsos Negativos
# 0.0% de Falsos Positivos
# ______________________________________________________
# ______________________________________________________
# 85.6% de Verdadeiros Positivos
# 14.4% de Verdadeiros Negativos
# 0.0% de Falsos Negativos
# 0.0% de Falsos Positivos
# ______________________________________________________
# ______________________________________________________
# 82.2% de Verdadeiros Positivos
# 17.8% de Verdadeiros Negativos
# 0.0% de Falsos Negativos
# 0.0% de Falsos Positivos
# ______________________________________________________
# ______________________________________________________
# 82.6% de Verdadeiros Positivos
# 17.4% de Verdadeiros Negativos
# 0.0% de Falsos Negativos
# 0.0% de Falsos Positivos
# ______________________________________________________
# ______________________________________________________
# 82.2% de Verdadeiros Positivos
# 17.8% de Verdadeiros Negativos
# 0.0% de Falsos Negativos
# 0.0% de Falsos Positivos
# ______________________________________________________
# ______________________________________________________
# 84.3% de Verdadeiros Positivos
# 15.7% de Verdadeiros Negativos
# 0.0% de Falsos Negativos
# 0.0% de Falsos Positivos
# ______________________________________________________
# ______________________________________________________
# 82.6% de Verdadeiros Positivos
# 17.4% de Verdadeiros Negativos
# 0.0% de Falsos Negativos
# 0.0% de Falsos Positivos
# ______________________________________________________
# ______________________________________________________
# 80.9% de Verdadeiros Positivos
# 19.1% de Verdadeiros Negativos
# 0.0% de Falsos Negativos
# 0.0% de Falsos Positivos
# ______________________________________________________
# ______________________________________________________
# 80.1% de Verdadeiros Positivos
# 19.9% de Verdadeiros Negativos
# 0.0% de Falsos Negativos
# 0.0% de Falsos Positivos
# ______________________________________________________
# ______________________________________________________
# 78.4% de Verdadeiros Positivos
# 21.6% de Verdadeiros Negativos
# 0.0% de Falsos Negativos
# 0.0% de Falsos Positivos
# ______________________________________________________
# ______________________________________________________
# 77.1% de Verdadeiros Positivos
# 22.9% de Verdadeiros Negativos
# 0.0% de Falsos Negativos
# 0.0% de Falsos Positivos
# ______________________________________________________
# ______________________________________________________
# 78.4% de Verdadeiros Positivos
# 21.6% de Verdadeiros Negativos
# 0.0% de Falsos Negativos
# 0.0% de Falsos Positivos
# ______________________________________________________
# ______________________________________________________
# 80.1% de Verdadeiros Positivos
# 19.9% de Verdadeiros Negativos
# 0.0% de Falsos Negativos
# 0.0% de Falsos Positivos
# ______________________________________________________
# ______________________________________________________
# 77.1% de Verdadeiros Positivos
# 22.9% de Verdadeiros Negativos
# 0.0% de Falsos Negativos
# 0.0% de Falsos Positivos
# ______________________________________________________
# ______________________________________________________
# 71.2% de Verdadeiros Positivos
# 28.8% de Verdadeiros Negativos
# 0.0% de Falsos Negativos
# 0.0% de Falsos Positivos
# ______________________________________________________
# ______________________________________________________
# 75.8% de Verdadeiros Positivos
# 24.2% de Verdadeiros Negativos
# 0.0% de Falsos Negativos
# 0.0% de Falsos Positivos
# ______________________________________________________
# ______________________________________________________
# 75.8% de Verdadeiros Positivos
# 24.2% de Verdadeiros Negativos
# 0.0% de Falsos Negativos
# 0.0% de Falsos Positivos
# ______________________________________________________
# ______________________________________________________
# 74.2% de Verdadeiros Positivos
# 25.8% de Verdadeiros Negativos
# 0.0% de Falsos Negativos
# 0.0% de Falsos Positivos
# ______________________________________________________
# ______________________________________________________
# 73.3% de Verdadeiros Positivos
# 26.7% de Verdadeiros Negativos
# 0.0% de Falsos Negativos
# 0.0% de Falsos Positivos
# ______________________________________________________
# ______________________________________________________
# 76.3% de Verdadeiros Positivos
# 23.7% de Verdadeiros Negativos
# 0.0% de Falsos Negativos
# 0.0% de Falsos Positivos
# ______________________________________________________
# ______________________________________________________
# 80.1% de Verdadeiros Positivos
# 19.9% de Verdadeiros Negativos
# 0.0% de Falsos Negativos
# 0.0% de Falsos Positivos
# ______________________________________________________
# ______________________________________________________
# 80.1% de Verdadeiros Positivos
# 19.9% de Verdadeiros Negativos
# 0.0% de Falsos Negativos
# 0.0% de Falsos Positivos
# ______________________________________________________
# ______________________________________________________
# 79.7% de Verdadeiros Positivos
# 20.3% de Verdadeiros Negativos
# 0.0% de Falsos Negativos
# 0.0% de Falsos Positivos
# ______________________________________________________
# ______________________________________________________
# 78.8% de Verdadeiros Positivos
# 21.2% de Verdadeiros Negativos
# 0.0% de Falsos Negativos
# 0.0% de Falsos Positivos
# ______________________________________________________
# ______________________________________________________
# 80.5% de Verdadeiros Positivos
# 19.5% de Verdadeiros Negativos
# 0.0% de Falsos Negativos
# 0.0% de Falsos Positivos
# ______________________________________________________
# ______________________________________________________
# 82.6% de Verdadeiros Positivos
# 17.4% de Verdadeiros Negativos
# 0.0% de Falsos Negativos
# 0.0% de Falsos Positivos
# ______________________________________________________
# ______________________________________________________
# 79.7% de Verdadeiros Positivos
# 20.3% de Verdadeiros Negativos
# 0.0% de Falsos Negativos
# 0.0% de Falsos Positivos
# ______________________________________________________
# ______________________________________________________
# 78.0% de Verdadeiros Positivos
# 22.0% de Verdadeiros Negativos
# 0.0% de Falsos Negativos
# 0.0% de Falsos Positivos
# ______________________________________________________
# ______________________________________________________
# 76.7% de Verdadeiros Positivos
# 23.3% de Verdadeiros Negativos
# 0.0% de Falsos Negativos
# 0.0% de Falsos Positivos
# ______________________________________________________
# ______________________________________________________
# 74.6% de Verdadeiros Positivos
# 25.4% de Verdadeiros Negativos
# 0.0% de Falsos Negativos
# 0.0% de Falsos Positivos
# ______________________________________________________
# ______________________________________________________
# 73.3% de Verdadeiros Positivos
# 26.7% de Verdadeiros Negativos
# 0.0% de Falsos Negativos
# 0.0% de Falsos Positivos
# ______________________________________________________
# ______________________________________________________
# 75.4% de Verdadeiros Positivos
# 24.6% de Verdadeiros Negativos
# 0.0% de Falsos Negativos
# 0.0% de Falsos Positivos
# ______________________________________________________
# ______________________________________________________
# 79.2% de Verdadeiros Positivos
# 20.8% de Verdadeiros Negativos
# 0.0% de Falsos Negativos
# 0.0% de Falsos Positivos
# ______________________________________________________
# ______________________________________________________
# 77.5% de Verdadeiros Positivos
# 22.5% de Verdadeiros Negativos
# 0.0% de Falsos Negativos
# 0.0% de Falsos Positivos
# ______________________________________________________
# ______________________________________________________
# 76.7% de Verdadeiros Positivos
# 23.3% de Verdadeiros Negativos
# 0.0% de Falsos Negativos
# 0.0% de Falsos Positivos
# ______________________________________________________
# ______________________________________________________
# 78.0% de Verdadeiros Positivos
# 22.0% de Verdadeiros Negativos
# 0.0% de Falsos Negativos
# 0.0% de Falsos Positivos
# ______________________________________________________
# ______________________________________________________
# 77.5% de Verdadeiros Positivos
# 22.5% de Verdadeiros Negativos
# 0.0% de Falsos Negativos
# 0.0% de Falsos Positivos
# ______________________________________________________
# ______________________________________________________
# 78.8% de Verdadeiros Positivos
# 21.2% de Verdadeiros Negativos
# 0.0% de Falsos Negativos
# 0.0% de Falsos Positivos
# ______________________________________________________
# ______________________________________________________
# 78.4% de Verdadeiros Positivos
# 21.6% de Verdadeiros Negativos
# 0.0% de Falsos Negativos
# 0.0% de Falsos Positivos
# ______________________________________________________
# ______________________________________________________
# 77.1% de Verdadeiros Positivos
# 22.9% de Verdadeiros Negativos
# 0.0% de Falsos Negativos
# 0.0% de Falsos Positivos
# ______________________________________________________
# ______________________________________________________
# 77.5% de Verdadeiros Positivos
# 22.5% de Verdadeiros Negativos
# 0.0% de Falsos Negativos
# 0.0% de Falsos Positivos
# ______________________________________________________
# ______________________________________________________
# 78.0% de Verdadeiros Positivos
# 22.0% de Verdadeiros Negativos
# 0.0% de Falsos Negativos
# 0.0% de Falsos Positivos
# ______________________________________________________
# ______________________________________________________
# 77.5% de Verdadeiros Positivos
# 22.5% de Verdadeiros Negativos
# 0.0% de Falsos Negativos
# 0.0% de Falsos Positivos
# ______________________________________________________
# ______________________________________________________
# 80.5% de Verdadeiros Positivos
# 19.5% de Verdadeiros Negativos
# 0.0% de Falsos Negativos
# 0.0% de Falsos Positivos
# ______________________________________________________
# ______________________________________________________
# 78.8% de Verdadeiros Positivos
# 21.2% de Verdadeiros Negativos
# 0.0% de Falsos Negativos
# 0.0% de Falsos Positivos
# ______________________________________________________
# ______________________________________________________
# 80.9% de Verdadeiros Positivos
# 19.1% de Verdadeiros Negativos
# 0.0% de Falsos Negativos
# 0.0% de Falsos Positivos
# ______________________________________________________
# ______________________________________________________
# 78.8% de Verdadeiros Positivos
# 21.2% de Verdadeiros Negativos
# 0.0% de Falsos Negativos
# 0.0% de Falsos Positivos
# ______________________________________________________
# ______________________________________________________
# 80.1% de Verdadeiros Positivos
# 19.9% de Verdadeiros Negativos
# 0.0% de Falsos Negativos
# 0.0% de Falsos Positivos
# ______________________________________________________
# ______________________________________________________
# 79.7% de Verdadeiros Positivos
# 20.3% de Verdadeiros Negativos
# 0.0% de Falsos Negativos
# 0.0% de Falsos Positivos
# ______________________________________________________

# %%
plt.figure(figsize=(15, 10))

plt.subplot(221)
plt.hist(lista_acertos_relevantes, edgecolor='white', color='green')
plt.title('Taxa de positivos corretos')

plt.subplot(222)
plt.hist(lista_acertos_irrelevantes, edgecolor='white', color='red')
plt.title('Taxa de negativos corretos')

plt.show()

# %% [markdown]
# ___
# # <kbd><code style="font-family:Times New Roman;background:black;color:white"> Aperfeiçoamento</code></kbd>
# Os trabalhos vão evoluir em conceito dependendo da quantidade de itens avançados:
#
# * Limpar: \n, :, ", ', (, ), etc SEM remover emojis
# * Corrigir separação de espaços entre palavras e emojis ou entre emojis e emojis
# * Propor outras limpezas e transformações que não afetem a qualidade da informação ou classificação
# * Criar categorias intermediárias de relevância baseadas na probabilidade: ex.: muito relevante, relevante, neutro, irrelevante, muito irrelevante (3 categorias: C, mais categorias conta para B)
# * Explicar por que não posso usar o próprio classificador para gerar mais amostras de treinamento
# * Propor diferentes cenários para Naïve Bayes fora do contexto do projeto
# * Sugerir e explicar melhorias reais com indicações concretas de como implementar (indicar como fazer e indicar material de pesquisa)

# %% [markdown]
# ___
# # <kbd><code style="font-family:Times New Roman;background:black;color:white"> Referências</code></kbd>

# %% [markdown]
# [Naive Bayes and Text Classification](https://arxiv.org/pdf/1410.5329.pdf)  **Mais completo**
#
# [A practical explanation of a Naive Bayes Classifier](https://monkeylearn.com/blog/practical-explanation-naive-bayes-classifier/) **Mais simples**
